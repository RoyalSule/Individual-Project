# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

# %%
from src.data_loader import DataLoader

dataLoader = DataLoader()
dataLoader.download()
dataLoader.clean()
dataLoader.add_features()
dataLoader.add_technical_indicators()
sp500 = dataLoader.data

# %%
import pandas as pd

sp500.index = pd.to_datetime(sp500.index)
sp500 = sp500.loc["1990-01-01":].copy()
sp500 = sp500.dropna(subset=sp500.columns[sp500.columns!="Tomorrow"])

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2026-04-21 00:00:00-04:00  7122.640137  7137.270020  7050.200195  7064.009766
# 2026-04-22 00:00:00-04:00  7102.910156  7138.640137  7102.910156  7137.899902
# 2026-04-23 00:00:00-04:00  7118.799805  7147.779785  7046.549805  7108.399902
# 2026-04-24 00:00:00-04:00  7136.479980  7168.589844  7112.819824  7165.080078
# 2026-04-27 00:00:00-04:00  7152.720215  7178.740234  7146.720215  7173.910156
#
#                                Volume     Tomorrow  Target  Close_Ratio_2  \
# Date
# 1990-01-02 00:00:00-05:00   162070000   358.760010       0       1.008821
# 1990-01-03 00:00:00-05:00   192330000   355.670013       0       0.998706
# 1990-01-04 00:00:00-05:00   177000000   352.200012       0       0.995675
# 1990-01-05 00:00:00-05:00   158530000   353.790009       1       0.995098
# 1990-01-08 00:00:00-05:00   140110000   349.619995       0       1.002252
# ...                               ...          ...     ...            ...
# 2026-04-21 00:00:00-04:00  5160270000  7137.899902       1       0.996816
# 2026-04-22 00:00:00-04:00  4919460000  7108.399902       0       1.005203
# 2026-04-23 00:00:00-04:00  5307260000  7165.080078       1       0.997929
# 2026-04-24 00:00:00-04:00  4608830000  7173.910156       1       1.003971
# 2026-04-27 00:00:00-04:00  4783750000          NaN       0       1.000616
#
#                            Volume_Ratio_2  Trend_2  ...  Trend_1000  Body_Pct  \
# Date                                                ...
# 1990-01-02 00:00:00-05:00        1.052368      2.0  ...       568.0  1.779855
# 1990-01-03 00:00:00-05:00        1.085384      1.0  ...       568.0 -0.258554
# 1990-01-04 00:00:00-05:00        0.958492      0.0  ...       568.0 -0.861299
# 1990-01-05 00:00:00-05:00        0.944953      0.0  ...       568.0 -0.975624
# 1990-01-08 00:00:00-05:00        0.938320      1.0  ...       568.0  0.451447
# ...                                   ...      ...  ...         ...       ...
# 2026-04-21 00:00:00-04:00        1.050822      0.0  ...       539.0 -0.823155
# 2026-04-22 00:00:00-04:00        0.976109      1.0  ...       540.0  0.492611
# 2026-04-23 00:00:00-04:00        1.037920      1.0  ...       539.0 -0.146091
# 2026-04-24 00:00:00-04:00        0.929566      1.0  ...       539.0  0.400759
# 2026-04-27 00:00:00-04:00        1.018623      2.0  ...       540.0  0.296250
#
#                            Range_Pct        EMA_9       EMA_12       EMA_26  \
# Date
# 1990-01-02 00:00:00-05:00   2.143510   350.996152   350.146235   348.011372
# 1990-01-03 00:00:00-05:00   0.748768   352.548924   351.471431   348.807567
# 1990-01-04 00:00:00-05:00   1.636190   353.173142   352.117367   349.315897
# 1990-01-05 00:00:00-05:00   1.214611   352.978516   352.130082   349.529535
# 1990-01-08 00:00:00-05:00   1.044484   353.140814   352.385455   349.845125
# ...                              ...          ...          ...          ...
# 2026-04-21 00:00:00-04:00   1.219932  6978.148449  6930.680971  6823.991704
# 2026-04-22 00:00:00-04:00   0.500515  7010.098740  6962.560806  6847.244163
# 2026-04-23 00:00:00-04:00   1.416244  7029.758972  6984.997590  6866.589033
# 2026-04-24 00:00:00-04:00   0.777978  7056.823194  7012.702589  6888.699481
# 2026-04-27 00:00:00-04:00   0.446040  7080.240586  7037.503753  6909.826197
#
#                                  MACD  MACD_Signal  MACD_Histogram     ATR_14
# Date
# 1990-01-02 00:00:00-05:00    2.134864     1.273021        0.861843   3.599282
# 1990-01-03 00:00:00-05:00    2.663864     1.551190        1.112675   3.520711
# 1990-01-04 00:00:00-05:00    2.801471     1.801246        1.000225   3.764995
# 1990-01-05 00:00:00-05:00    2.600547     1.961106        0.639441   3.882852
# 1990-01-08 00:00:00-05:00    2.540330     2.076951        0.463379   3.734279
# ...                               ...          ...             ...        ...
# 2026-04-21 00:00:00-04:00  106.689267    52.653675       54.035592  81.064279
# 2026-04-22 00:00:00-04:00  115.316643    65.186268       50.130375  80.598598
# 2026-04-23 00:00:00-04:00  118.408558    75.830726       42.577831  78.760010
# 2026-04-24 00:00:00-04:00  124.003108    85.465203       38.537905  80.315744
# 2026-04-27 00:00:00-04:00  127.677556    93.907673       33.769882  76.623605
#
# [9146 rows x 31 columns]

# %%
sp500["Close"].plot.line(use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
last_60_days = sp500.iloc[-60:]

# EMA 9
last_60_days[['Close', 'EMA_9']].plot.line(use_index=True)

# MACD 
last_60_days[['MACD', 'MACD_Signal', 'MACD_Histogram']].plot.line(use_index=True)

# ATR 14
last_60_days[['ATR_14']].plot.line(use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
from sklearn.ensemble import RandomForestClassifier
from src.evaluate import backtest

model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

predictors = [
    # Technical indicators
    "EMA_9", "MACD", "MACD_Signal", "MACD_Histogram", "ATR_14",

    # Price action features
    "Close_Ratio_2", "Close_Ratio_5", "Close_Ratio_60", "Close_Ratio_250", "Close_Ratio_1000",
    "Volume_Ratio_2", "Volume_Ratio_5", "Volume_Ratio_60", "Volume_Ratio_250", "Volume_Ratio_1000",
    "Trend_2", "Trend_5", "Trend_60", "Trend_250", "Trend_1000",

    "Body_Pct", "Range_Pct"
]

predictions = backtest(sp500, model, predictors)

# %%
predictions
# Out:
#                            Target  Predictions
# Date
# 1999-11-22 00:00:00-05:00       0            0
# 1999-11-23 00:00:00-05:00       1            0
# 1999-11-24 00:00:00-05:00       0            0
# 1999-11-26 00:00:00-05:00       0            0
# 1999-11-29 00:00:00-05:00       0            0
# ...                           ...          ...
# 2026-04-21 00:00:00-04:00       1            0
# 2026-04-22 00:00:00-04:00       0            0
# 2026-04-23 00:00:00-04:00       1            0
# 2026-04-24 00:00:00-04:00       1            0
# 2026-04-27 00:00:00-04:00       0            0
#
# [6646 rows x 2 columns]

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    6344
# 1     302
# Name: count, dtype: int64

# %%
from sklearn.metrics import precision_score

precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5794701986754967

# %%
from src.evaluate import add_returns, plot_equity_curve, plot_prediction_distribution, summary_metrics

predictions = add_returns(predictions, sp500)

# %%
plot_equity_curve(predictions, "Random Forest", sp500)

# %%
plot_prediction_distribution(predictions, "Random Forest")

# %%
summary_metrics(predictions, "Random Forest", sp500)
# Out:
# {'Model': 'Random Forest',
#  'Precision': 0.5795,
#  'Sharpe Ratio': 0.5529,
#  'Strategy Return': 0.8392,
#  'Buy & Hold Return': 2.1098,
#  'MA Crossover Return': 1.8914,
#  'Number of Trades': 302}

# %%
import matplotlib.pyplot as plt

importances = pd.Series(model.feature_importances_, index=predictors)
importances.sort_values().plot.barh(
    figsize=(10, 6),
    title='Feature Importances — Random Forest'
)
plt.tight_layout()
plt.show()

# %%
import joblib

joblib.dump(predictions, '../models/predictions_rf.joblib')
# Out:
# ['../models/predictions_rf.joblib']
